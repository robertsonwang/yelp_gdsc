# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import scrapping_functions as sf
reload(sf)

base_url = 'https://www.yelp.com'

# %%
link_file = open("cleanbiz_links_2.txt", "r")
link_list = link_file.read().split('\n')
link_list = list(set(link_list))

# %%
link_list[33]
# Out:
# '/biz/the-codmother-washington?osq=Restaurants'

# %%
json_dict = {}
for link in link_list:
    reviews = sf.scrap_reviews(link, base_url)
    if type(reviews) == dict:
        json_dict[link] = reviews
    else:
        print reviews
        break

# %%
with open('dc_reviews_2.json', 'w') as outfile:
    json.dump(json_dict, outfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a4b473b37e1f> in <module>()
#       1 with open('dc_reviews_2.json', 'w') as outfile:
# ----> 2     json.dump(json_dict, outfile)
#
# NameError: name 'json_dict' is not defined

# %% [markdown]
# Load in Review Data

# %%
review_json = json.load(open("/Users/robertsonwang/Desktop/Python/Yelp/dc_reviews.json"))

# %%
review_json.keys()
# Out:
# [u'/biz/panas-washington',
#  u'/biz/las-placitas-washington-3',
#  u'/biz/ardeo-bardeo-washington',
#  u'/biz/el-centro-df-14th-st-washington',
#  u'/biz/calabash-teahouse-and-cafe-washington',
#  u'/biz/nido-washington-2',
#  u'/biz/stoneys-on-l-washington',
#  u'/biz/blue-44-restaurant-and-bar-washington',
#  u'/biz/roti-modern-mediterranean-washington',
#  u'/biz/flight-wine-bar-washington',
#  u'/biz/red-toque-cafe-washington-3',
#  u'/biz/m%C3%A9tier-washington-4',
#  u'/biz/lincoln-park-kitchen-and-wine-bar-washington',
#  u'/biz/zaytinya-washington',
#  u'/biz/zippin-chickin-washington',
#  u'/biz/philos-washington',
#  u'/biz/momofuku-ccdc-washington',
#  u'/biz/district-taco-washington-6',
#  u'/biz/letena-ethiopian-restaurant-washington',
#  u'/biz/espita-mezcaleria-washington',
#  u'/biz/macintyres-washington',
#  u'/biz/barrel-washington',
#  u'/biz/lapis-washington',
#  u'/biz/quill-washington',
#  u'/biz/ambar-washington',
#  u'/biz/brasserie-beck-washington-3',
#  u'/biz/hanks-cocktail-bar-washington',
#  u'/biz/busboys-and-poets-washington-5',
#  u'/biz/proof-restaurant-washington',
#  u'/biz/busboys-and-poets-washington-9',
#  u'/biz/casa-luca-washington',
#  u'/biz/jyoti-indian-cuisine-washington',
#  u'/biz/otello-washington',
#  u'/biz/ruths-chris-steak-house-washington',
#  u'/biz/flavio-restaurant-washington',
#  u'/biz/the-red-hen-washington',
#  u'/biz/filomena-ristorante-washington',
#  u'/biz/pho-viet-washington',
#  u'/biz/zannchi-washington',
#  u'/biz/grand-trunk-washington',
#  u'/biz/hitching-post-washington',
#  u'/biz/bareburger-washington',
#  u'/biz/barmini-by-jos%C3%A9-andr%C3%A9s-washington-4',
#  u'/biz/fiola-washington',
#  u'/biz/yosaku-japanese-restaurant-washington',
#  u'/biz/zorbas-cafe-washington',
#  u'/biz/colada-shop-washington',
#  u'/biz/kokeb-ethiopian-restaurant-washington',
#  u'/biz/cafe-ol%C3%A9-washington-2',
#  u'/biz/brooklands-finest-washington-2',
#  u'/biz/terasol-washington',
#  u'/biz/pamplona-arlington',
#  u'/biz/charlie-palmer-steak-washington',
#  u'/biz/shophouse-southeast-asian-kitchen-washington-8',
#  u'/biz/shophouse-southeast-asian-kitchen-washington-6',
#  u'/biz/2-amys-neapolitan-pizzeria-washington',
#  u'/biz/highlands-washington-3',
#  u'/biz/mari-vanna-dc-washington-2',
#  u'/biz/sushi-taro-washington',
#  u'/biz/joselito-washington',
#  u'/biz/pier-2934-cajun-seafood-washington',
#  u'/biz/takoda-restaurant-and-beer-garden-washington-2',
#  u'/biz/off-the-record-washington',
#  u'/biz/the-queen-vic-washington',
#  u'/biz/osteria-morini-washington',
#  u'/biz/nook-washington-2',
#  u'/biz/busboys-and-poets-washington-10',
#  u'/biz/corduroy-washington-4',
#  u'/biz/maketto-washington-2',
#  u'/biz/bluejacket-washington',
#  u'/biz/dolan-uyghur-restaurant-washington-2',
#  u'/biz/thally-washington',
#  u'/biz/fiola-mare-washington',
#  u'/biz/right-proper-brewing-company-washington-2',
#  u'/biz/aperto-washington',
#  u'/biz/pineapple-and-pearls-washington-3',
#  u'/biz/iron-gate-washington',
#  u'/biz/the-lafayette-washington-3',
#  u'/biz/el-chal%C3%A1n-washington-3',
#  u'/biz/mandu-washington-2',
#  u'/biz/moxies-washington',
#  u'/biz/cusbah-washington',
#  u'/biz/the-rye-bar-washington',
#  u'/biz/yafa-grille-washington',
#  u'/biz/afghan-grill-washington',
#  u'/biz/chaplins-washington',
#  u'/biz/raku-washington-3',
#  u'/biz/via-umbria-washington',
#  u'/biz/momoyama-washington',
#  u'/biz/the-source-washington',
#  u'/biz/nagomi-izakaya-washington-2',
#  u'/biz/korean-signature-bibimbap-washington',
#  u'/biz/alta-strada-washington',
#  u'/biz/lukes-lobster-georgetown-washington',
#  u'/biz/siam-house-thai-restaurant-washington',
#  u'/biz/radiator-washington-2',
#  u'/biz/daikaya-izakaya-washington-8',
#  u'/biz/exiles-bar-washington',
#  u'/biz/cafe-aria-washington',
#  u'/biz/hanks-oyster-bar-washington',
#  u'/biz/zentan-restaurant-washington',
#  u'/biz/indique-washington',
#  u'/biz/kinship-washington',
#  u'/biz/honeygrow-washington',
#  u'/biz/the-dabney-washington',
#  u'/biz/gw-delicatessen-washington',
#  u'/biz/etto-washington',
#  u'/biz/capitol-hill-crab-cakes-washington',
#  u'/biz/bibap-washington',
#  u'/biz/medium-rare-washington-2',
#  u'/biz/rasika-west-end-washington',
#  u'/biz/montmartre-washington',
#  u'/biz/checheho-ethiopian-restaurant-falls-church-2',
#  u'/biz/dc-noodles-washington-6',
#  u'/biz/bozzellis-washington',
#  u'/biz/bens-upstairs-washington',
#  u'/biz/the-prospect-washington',
#  u'/biz/kellari-taverna-washington-2',
#  u'/biz/soi-38-washington-2',
#  u'/biz/pupuseria-san-miguel-washington',
#  u'/biz/umi-japanese-cuisine-washington-2',
#  u'/biz/mad-fox-taproom-washington-4',
#  u'/biz/yafa-grille-washington-4',
#  u'/biz/nazca-mochica-washington-2',
#  u'/biz/giovannis-trattu-washington',
#  u'/biz/the-partisan-washington',
#  u'/biz/cafe-grande-washington',
#  u'/biz/woodward-table-washington',
#  u'/biz/seasons-restaurant-washington',
#  u'/biz/thai-pad-washington-3',
#  u'/biz/jennys-at-the-wharf-washington',
#  u'/biz/plume-washington',
#  u'/biz/bonchon-washington',
#  u'/biz/cava-washington',
#  u'/biz/brookland-pint-washington-10',
#  u'/biz/la-piquette-washington',
#  u'/biz/pow-pow-washington',
#  u'/biz/restaurant-nora-washington',
#  u'/biz/tadich-grill-washington',
#  u'/biz/oki-bowl-dc-and-sake-washington',
#  u'/biz/kalye-dc-washington',
#  u'/biz/nicks-riverside-grill-washington-2',
#  u'/biz/petworth-cafe-washington',
#  u'/biz/spice-of-bukhara-kabob-house-washington',
#  u'/biz/aboil-cafe-washington',
#  u'/biz/campono-washington',
#  u'/biz/rice-bar-washington',
#  u'/biz/rasika-washington',
#  u'/biz/honeysuckle-washington-3',
#  u'/biz/sushi-capitol-washington-3',
#  u'/biz/cava-mezze-washington-3',
#  u'/biz/mama-ayeshas-washington',
#  u'/biz/huacatay-peruvian-chicken-washington',
#  u'/biz/article-one-american-grill-washington',
#  u'/biz/bindaas-washington',
#  u'/biz/el-torogoz-washington',
#  u'/biz/aris-diner-washington',
#  u'/biz/the-pig-washington-2',
#  u'/biz/purple-patch-washington',
#  u'/biz/district-rico-washington-5',
#  u'/biz/hawthorne-washington',
#  u'/biz/masseria-washington-2',
#  u'/biz/la-jambe-washington',
#  u'/biz/acadiana-washington',
#  u'/biz/good-stuff-eatery-washington-2',
#  u'/biz/sakerum-washington-2',
#  u'/biz/sylvan-cafe-and-bakery-washington',
#  u'/biz/the-district-fishwife-washington',
#  u'/biz/buredo-washington-4',
#  u'/biz/taberna-del-alabardero-washington',
#  u'/biz/buredo-washington-3',
#  u'/biz/far-east-taco-grille-washington-5',
#  u'/biz/dukes-counter-washington',
#  u'/biz/bab-korean-fusion-washington-3',
#  u'/biz/taqueria-and-rosticeria-fresca-washington',
#  u'/biz/lets-mix-bibija-washington',
#  u'/biz/restaurant-judy-washington',
#  u'/biz/ocopa-washington',
#  u'/biz/convivial-washington',
#  u'/biz/and-pizza-washington-11',
#  u'/biz/casolare-ristorante-bar-washington',
#  u'/biz/shouk-washington',
#  u'/biz/lincoln-washington',
#  u'/biz/bistro-bis-washington',
#  u'/biz/arcuri-washington',
#  u'/biz/district-distilling-co-washington',
#  u'/biz/burger-tap-and-shake-washington-6',
#  u'/biz/rpm-italian-washington-4',
#  u'/biz/oceanaire-seafood-room-washington-3',
#  u'/biz/sushi-keiko-washington',
#  u'/biz/st-arnolds-mussel-bar-washington',
#  u'/biz/pho-14-washington',
#  u'/biz/drift-on-7th-washington',
#  u'/biz/dukes-grocery-washington',
#  u'/biz/taqueria-habanero-washington',
#  u'/biz/top-spanish-cafe-and-catering-washington',
#  u'/biz/el-fuego-washington-2',
#  u'/biz/himitsu-washington',
#  u'/biz/thip-khao-washington',
#  u'/biz/cantina-marina-washington',
#  u'/biz/s-and-g-seafood-house-washington',
#  u'/biz/usda-cafeteria-washington',
#  u'/biz/bourbon-steak-washington-3',
#  u'/biz/alfa-piehouse-washington',
#  u'/biz/the-airedale-washington',
#  u'/biz/jam-doung-style-cuisine-washington',
#  u'/biz/dirty-habit-washington-2',
#  u'/biz/beefsteak-washington-7',
#  u'/biz/the-haymaker-bar-washington',
#  u'/biz/anxo-cidery-and-pintxos-bar-washington',
#  u'/biz/macon-bistro-and-larder-washington',
#  u'/biz/breadsoda-washington',
#  u'/biz/lukes-lobster-penn-quarter-washington',
#  u'/biz/imm-thai-washington',
#  u'/biz/southern-efficiency-washington-2',
#  u'/biz/subbs-washington',
#  u'/biz/city-tap-house-washington',
#  u'/biz/sotto-washington',
#  u'/biz/barcelona-wine-bar-washington',
#  u'/biz/the-royal-washington-2',
#  u'/biz/salt-and-pepper-washington',
#  u'/biz/laliguras-indian-and-nepali-bistro-washington-2',
#  u'/biz/nopa-kitchen-bar-washington',
#  u'/biz/penn-grill-washington',
#  u'/biz/provision-no-14-washington',
#  u'/biz/garden-district-washington-3',
#  u'/biz/homestead-washington',
#  u'/biz/farmers-and-distillers-washington-2',
#  u'/biz/bangkok-joes-washington-4',
#  u'/biz/bold-bite-washington',
#  u'/biz/floriana-washington',
#  u'/biz/beucherts-saloon-washington',
#  u'/biz/tonton-chicken-washington',
#  u'/biz/tartufo-washington',
#  u'/biz/red-derby-washington-4',
#  u'/biz/1789-restaurant-washington-4',
#  u'/biz/peoples-bao-washington-3',
#  u'/biz/hot-n-juicy-crawfish-washington',
#  u'/biz/simit-smith-washington',
#  u'/biz/tabard-inn-restaurant-washington-2',
#  u'/biz/blue-duck-tavern-washington',
#  u'/biz/little-serow-washington',
#  u'/biz/boulangerie-christophe-washington',
#  u'/biz/old-ebbitt-grill-washington',
#  u'/biz/cava-washington-3',
#  u'/biz/cava-washington-4',
#  u'/biz/driftwood-kitchen-washington',
#  u'/biz/caf%C3%A9-sorriso-washington-2',
#  u'/biz/keren-restaurant-washington',
#  u'/biz/sushi-ogawa-washington',
#  u'/biz/blacksalt-washington-2',
#  u'/biz/teds-bulletin-washington',
#  u'/biz/al-tiramisu-washington',
#  u'/biz/tryst-washington',
#  u'/biz/abunai-washington',
#  u'/biz/toki-underground-washington',
#  u'/biz/indigo-washington-3',
#  u'/biz/siroc-restaurant-washington',
#  u'/biz/ottoman-taverna-washington',
#  u'/biz/los-hermanos-washington-2',
#  u'/biz/sallys-middle-name-washington',
#  u'/biz/prescription-chicken-washington-2',
#  u'/biz/tico-dc-washington-2',
#  u'/biz/clydes-of-georgetown-washington-3',
#  u'/biz/room-11-washington',
#  u'/biz/il-canale-washington-2',
#  u'/biz/bad-saint-washington',
#  u'/biz/unum-washington-2',
#  u'/biz/medium-rare-washington',
#  u'/biz/dish-drinks-washington',
#  u'/biz/a-deli-arlington-2',
#  u'/biz/2020-restaurant-and-lounge-washington',
#  u'/biz/art-and-soul-washington-2',
#  u'/biz/the-bird-washington',
#  u'/biz/the-smith-washington-2',
#  u'/biz/maple-washington',
#  u'/biz/potters-house-washington',
#  u'/biz/mezcalero-washington',
#  u'/biz/declaration-washington',
#  u'/biz/toro-toro-washington-2',
#  u'/biz/beef-n-bread-washington',
#  u'/biz/athena-grill-washington',
#  u'/biz/west-wing-cafe-washington-3',
#  u'/biz/willie-ts-lobster-shack-washington-3',
#  u'/biz/the-italians-kitchen-washington',
#  u'/biz/heat-da-spot-washington',
#  u'/biz/medaterra-washington',
#  u'/biz/malbec-restaurant-washington-2',
#  u'/biz/the-big-stick-washington-2',
#  u'/biz/archipelago-washington-2',
#  u'/biz/little-red-fox-washington',
#  u'/biz/fare-well-washington-2',
#  u'/biz/the-passenger-washington',
#  u'/biz/tropic-burger-washington',
#  u'/biz/dinos-grotto-washington-5',
#  u'/biz/circa-at-foggy-bottom-washington-2',
#  u'/biz/district-supper-washington',
#  u'/biz/due-south-washington-2',
#  u'/biz/sunrise-caribbean-restaurant-washington',
#  u'/biz/byblos-deli-washington',
#  u'/biz/district-commons-washington-3',
#  u'/biz/firefly-washington',
#  u'/biz/the-dew-drop-inn-washington',
#  u'/biz/ching-ching-cha-washington',
#  u'/biz/801-restaurant-and-bar-washington',
#  u'/biz/pho-12-washington-2',
#  u'/biz/red-apron-burger-bar-washington-2',
#  u'/biz/district-of-pi-washington',
#  u'/biz/il-parco-washington-3',
#  u'/biz/scarlet-oak-washington',
#  u'/biz/dc-ballers-food-truck-washington',
#  u'/biz/pennsylvania-6-dc-washington',
#  u'/biz/sudhouse-washington',
#  u'/biz/b-penn-quarter-washington-2',
#  u'/biz/slash-run-washington',
#  u'/biz/station-4-washington-3',
#  u'/biz/agora-washington',
#  u'/biz/smokeys-washington-3',
#  u'/biz/simply-banh-mi-washington-3',
#  u'/biz/garden-cafe-washington-5',
#  u'/biz/thai-and-pho-bistro-washington',
#  u'/biz/lebanese-taverna-washington',
#  u'/biz/all-purpose-pizzeria-washington',
#  u'/biz/gcdc-grilled-cheese-bar-washington',
#  u'/biz/barcelona-wine-bar-cathedral-heights-washington-2',
#  u'/biz/bistro-cacao-washington-2',
#  u'/biz/acqua-al-2-washington',
#  u'/biz/ten-tigers-parlour-washington',
#  u'/biz/smoke-and-barrel-washington',
#  u'/biz/dc-harvest-washington-3',
#  u'/biz/quinns-on-the-corner-arlington',
#  u'/biz/honeysuckle-washington',
#  u'/biz/sumahs-washington',
#  u'/biz/makoto-restaurant-washington',
#  u'/biz/the-pub-and-the-people-washington',
#  u'/biz/copycat-co-washington-2',
#  u'/biz/blt-steak-washington-2',
#  u'/biz/churchkey-washington',
#  u'/biz/rice-bar-washington-3',
#  u'/biz/rice-bar-washington-4',
#  u'/biz/palm-restaurant-washington',
#  u'/biz/timgad-cafe-washington-6',
#  u'/biz/mythology-washington',
#  u'/biz/the-alibi-washington',
#  u'/biz/boqueria-washington',
#  u'/biz/central-michel-richard-washington',
#  u'/biz/wicked-waffle-washington',
#  u'/biz/lemon-cuisine-of-india-washington',
#  u'/biz/flippin-pizza-washington-4',
#  u'/biz/the-hilltop-bar-and-restaurant-washington',
#  u'/biz/nandos-peri-peri-washington-9',
#  u'/biz/pidzza-washington',
#  u'/biz/roses-luxury-washington',
#  u'/biz/mintwood-place-washington',
#  u'/biz/the-sovereign-washington-3',
#  u'/biz/and-pizza-washington-46',
#  u'/biz/skwr-kabobline-washington',
#  u'/biz/right-spot-restaurant-and-bar-washington',
#  u'/biz/capitol-city-brewing-company-washington-3',
#  u'/biz/roti-modern-mediterranean-washington-7',
#  u'/biz/roti-modern-mediterranean-washington-2',
#  u'/biz/bistrot-du-coin-washington',
#  u'/biz/ocean-prime-washington',
#  u'/biz/the-prime-rib-washington',
#  u'/biz/mourayo-washington',
#  u'/biz/the-commodore-public-house-and-kitchen-washington',
#  u'/biz/lavagna-washington',
#  u'/biz/shanghai-tokyo-cafe-washington',
#  u'/biz/7th-hill-pizza-palisades-washington',
#  u'/biz/spicy-delight-washington',
#  u'/biz/basil-thyme-washington',
#  u'/biz/old-engine-12-restaurant-washington',
#  u'/biz/donburi-washington',
#  u'/biz/navy-mess-and-ward-room-washington',
#  u'/biz/havana-cafe-washington',
#  u'/biz/curry-and-pie-washington',
#  u'/biz/komi-washington',
#  u'/biz/madrid-washington',
#  u'/biz/russia-house-restaurant-and-lounge-washington-2',
#  u'/biz/da-hong-pao-washington',
#  u'/biz/obelisk-washington',
#  u'/biz/minibar-by-jos%C3%A9-andr%C3%A9s-washington-7',
#  u'/biz/district-kitchen-washington',
#  u'/biz/red-white-and-basil-washington',
#  u'/biz/takorean-korean-taco-grill-washington-2',
#  u'/biz/vietnamese-chelsea-restaurant-washington',
#  u'/biz/daikaya-ramen-shop-washington',
#  u'/biz/the-capital-grille-washington-2',
#  u'/biz/whaleys-washington',
#  u'/biz/cornerstone-cafe-washington',
#  u'/biz/hazel-washington',
#  u'/biz/that-cheesecake-truck-washington-2',
#  u'/biz/mi-cuba-cafe-washington',
#  u'/biz/ben-tre-washington',
#  u'/biz/1831-bar-and-lounge-washington',
#  u'/biz/open-city-washington',
#  u'/biz/old-city-market-and-oven-washington',
#  u'/biz/tail-up-goat-washington',
#  u'/biz/haikan-washington',
#  u'/biz/trattoria-alberto-washington',
#  u'/biz/founding-farmers-dc-washington-2',
#  u'/biz/nandos-peri-peri-washington-8',
#  u'/biz/little-cocos-washington',
#  u'/biz/dumplings-and-beyond-washington',
#  u'/biz/and-pizza-washington-36',
#  u'/biz/china-boy-washington',
#  u'/biz/smith-public-trust-washington',
#  u'/biz/10-tavern-washington',
#  u'/biz/eatbar-washington',
#  u'/biz/st-arnolds-on-jefferson-washington',
#  u'/biz/nuvegan-caf%C3%A9-washington-2',
#  u'/biz/amsterdam-falafelshop-washington-2',
#  u'/biz/amsterdam-falafelshop-washington-4',
#  u'/biz/amsterdam-falafelshop-washington-5',
#  u'/biz/steel-plate-washington-2',
#  u'/biz/bar-civita-washington',
#  u'/biz/jardenea-washington',
#  u'/biz/el-sol-restaurante-washington',
#  u'/biz/boundary-road-washington',
#  u'/biz/straw-stick-and-brick-washington',
#  u'/biz/federalist-pig-washington-3',
#  u'/biz/et-voila-washington',
#  u'/biz/ezme-restaurant-and-wine-bar-washington-3',
#  u'/biz/uni-bistro-washington',
#  u'/biz/birch-and-barley-washington',
#  u'/biz/teds-bulletin-washington-3',
#  u'/biz/carving-room-washington',
#  u'/biz/ghibellina-washington',
#  u'/biz/farmers-fishers-bakers-washington',
#  u'/biz/ethiopic-washington',
#  u'/biz/joes-seafood-prime-steak-and-stone-crab-washington',
#  u'/biz/northside-10-alexandria',
#  u'/biz/rosa-mexicano-washington',
#  u'/biz/the-regent-washington-2',
#  u'/biz/astor-mediterranean-washington',
#  u'/biz/umaya-izakaya-washington-4',
#  u'/biz/the-dubliner-washington',
#  u'/biz/kingbird-washington',
#  u'/biz/romeo-and-juliet-washington',
#  u'/biz/jojo-restaurant-and-bar-washington',
#  u'/biz/the-fainting-goat-washington',
#  u'/biz/al-volo-washington',
#  u'/biz/dc-reynolds-washington',
#  u'/biz/proper-21-washington',
#  u'/biz/hipcityveg-washington-3',
#  u'/biz/eatsa-washington-4',
#  u'/biz/pizzeria-paradiso-washington-4',
#  u'/biz/aroi-fine-thai-and-japanese-cuisine-washington',
#  u'/biz/panda-gourmet-washington',
#  u'/biz/sakuramen-washington',
#  u'/biz/hanks-oyster-bar-washington-2',
#  u'/biz/old-europe-washington',
#  u'/biz/timber-pizza-company-washington',
#  u'/biz/kabob-square-washington',
#  u'/biz/seoulspice-washington',
#  u'/biz/las-canteras-washington',
#  u'/biz/naked-lunch-washington',
#  u'/biz/tosca-washington',
#  u'/biz/reren-washington',
#  u'/biz/pearl-dive-oyster-palace-washington',
#  u'/biz/the-hamilton-washington',
#  u'/biz/shemalis-washington',
#  u'/biz/little-sesame-washington',
#  u'/biz/mulebone-washington',
#  u'/biz/tortino-restaurant-washington',
#  u'/biz/100-montaditos-washington-2',
#  u'/biz/smallfry-washington',
#  u'/biz/momiji-washington',
#  u'/biz/southern-hospitality-washington',
#  u'/biz/das-ethiopian-washington',
#  u'/biz/chaia-washington-3',
#  u'/biz/murry-and-pauls-restaurant-washington',
#  u'/biz/eat-the-rich-washington',
#  u'/biz/coppis-organic-restaurant-washington',
#  u'/biz/eatsplace-washington-2',
#  u'/biz/granville-moores-washington',
#  u'/biz/open-city-at-the-national-cathedral-washington-3',
#  u'/biz/mxdc-washington',
#  u'/biz/white-house-deli-washington',
#  u'/biz/grillfish-dc-washington',
#  u'/biz/sfoglina-washington',
#  u'/biz/el-rinconcito-cafe-washington',
#  u'/biz/cafe-deluxe-washington-2',
#  u'/biz/mitsitam-cafe-washington-3',
#  u'/biz/agua-301-washington-2',
#  u'/biz/rappahannock-oyster-bar-washington',
#  u'/biz/a-baked-joint-washington-9',
#  u'/biz/modern-market-eatery-washington',
#  u'/biz/ruta-del-vino-washington-2',
#  u'/biz/triple-b-fresh-washington',
#  u'/biz/matchbox-chinatown-washington',
#  u'/biz/conosci-washington',
#  u'/biz/bar-a-vin-washington',
#  u'/biz/compass-rose-washington-3',
#  u'/biz/zeitoun-washington-2',
#  u'/biz/le-diplomate-washington',
#  u'/biz/ristorante-la-perla-of-washington-washington-3',
#  u'/biz/slims-diner-washington-2',
#  u'/biz/estadio-washington',
#  u'/biz/far-east-taco-grille-washington-4',
#  u'/biz/crisp-kitchen-bar-washington',
#  u'/biz/kyirisan-washington',
#  u'/biz/marcels-by-robert-wiedmaier-washington',
#  u'/biz/la-puerta-verde-washington',
#  u'/biz/brick-lane-washington',
#  u'/biz/kotobuki-washington',
#  u'/biz/bul-washington']

# %%
agg_dict = dict(review_json, **json_dict)

# %%
with open('dc_reviews_agg.json', 'w') as outfile:
    json.dump(agg_dict, outfile)
